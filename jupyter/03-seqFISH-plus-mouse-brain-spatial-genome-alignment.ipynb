# %% [markdown]
# ### Getting started

# %%
import warnings

warnings.filterwarnings("ignore", message="Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.")

import numpy as np
import pandas as pd
import copy
import tqdm
import matplotlib.pyplot as plt

from collections import defaultdict

###
from jie import plot
from jie import aligner

###
# Multiprocessing
import multiprocessing.pool as mpp
from multiprocessing.pool import ThreadPool as Pool

# from https://stackoverflow.com/questions/57354700/starmap-combined-with-tqdm
# Author: Darkonaut (08/05/2019)

def istarmap(self, func, iterable, chunksize=1):
    """starmap-version of imap
    """
    self._check_running()
    if chunksize < 1:
        raise ValueError(
            "Chunksize must be 1+, not {0:n}".format(
                chunksize))

    task_batches = mpp.Pool._get_tasks(func, iterable, chunksize)
    result = mpp.IMapIterator(self)
    self._taskqueue.put(
        (
            self._guarded_task_generation(result._job,
                                          mpp.starmapstar,
                                          task_batches),
            result._set_length
        ))
    return (item for chunk in result for item in chunk)

mpp.Pool.istarmap = istarmap

# %% [markdown]
# ### Download data
# - Here, we will download seqFISH+ whole genome tracing of __mouse brain__ (Takei _et al., Science_ __374__, 586-596 (2021)).
# <br></br>
# - This is an <font color=red>__incredibly rich dataset__</font>, replete with...
#     - `immunofluorescence imaging` of multiple histone modifications
#     - super-resolved `DNA positions` imaged at 2 resolutions:
#         - `1 Mb` (spans whole-genome)
#         - `25 kb` (spans ~ 1.5 Mb of each mouse chromosome)
#     - Below, we only download the super-resolved DNA positions.
# <br></br>
# - `jie` assumes the candidate spots are already decoded (ie. a table of (`x`, `y`, `z`) spatial coordinates), instead of working with raw imaging data.

# %%
# %%bash
# dir='../data/mbrain'
# if [[ ! -e $dir ]]; then
#     mkdir ../data/mbrain
#     wget -i ../data/mbrain_seqfish_urls.txt -P ../data/mbrain
# fi

# %% [markdown]
# ### Reference genome
# - Next, we build a __reference table of genomic distances__ (`df_refgen`) that separate imaged probes.
#     - This is critical for us to estimate an __expected spatial distance__, to which we compare the __observed spatial distance__ separating two imaged loci.
# <br></br>
# - Of note, this probe set was used much __earlier__ to image mouse embryonic stem cells (mESCs) (Takei _et al., Nature_ __590__, 344-350 (2021))
#     - Theses coordinates below correspond to this earlier work's [Supplementary Table 1](https://static-content.springer.com/esm/art%3A10.1038%2Fs41586-020-03126-2/MediaObjects/41586_2020_3126_MOESM2_ESM.xlsx)

# %%
df = pd.read_csv("../data/TableS0_Mbcoords.csv")

# find genomic distance between each bin 
df_list = []

# for every chromosome
for chrom, group in df.groupby('Chrom'):
    
    # find genomic distance relative to preceding bin
    _df = copy.deepcopy(group)
    
    # sort by start
    _df.sort_values(by='Start', inplace = True)
    
    # record relative region ID (relative to chrom start site)
    _df['hyb'] = [i for i in range(_df.shape[0])]
    
    # calculate genomic distance relative to first starting position
    _df['delta'] = _df['Start'] - _df['Start'].iloc[0]
            
    df_list.append(_df)

# merge all dataframes
df_refgen = pd.concat(df_list)

# %%
df_refgen
# Out:
#       Region ID      Name  Channel Chrom      Start        End  Chrom ID  hyb  \
# 0             1   chr1-#1        1  chr1    3100000    3125000         1    0
# 1             2   chr1-#2        1  chr1    5000000    5025000         1    1
# 2             3   Atp6v1h        2  chr1    5057518    5082518         1    2
# 3             4   chr1-#3        1  chr1    7000000    7025000         1    3
# 4             5   chr1-#4        1  chr1    8800000    8825000         1    4
# ...         ...       ...      ...   ...        ...        ...       ...  ...
# 2455       2456     Gpm6b        2  chrX  166226411  166251411        20  115
# 2456       2457  chrX-#59        1  chrX  167225000  167250000        20  116
# 2457       2458      Tlr7        2  chrX  167318058  167343058        20  117
# 2458       2459  chrX-#60        1  chrX  169025000  169050000        20  118
# 2459       2460      Mid1        2  chrX  169672699  169697699        20  119
#
#           delta
# 0             0
# 1       1900000
# 2       1957518
# 3       3900000
# 4       5700000
# ...         ...
# 2455  160501411
# 2456  161500000
# 2457  161593058
# 2458  163300000
# 2459  163947699
#
# [2460 rows x 9 columns]

# %% [markdown]
# ### Candidate spatial coordinates
# - We load decoded spatial coordinates of imaged genomic loci as a table (`df_seqfish`).

# %%
### HELPER FXN ###
def map_to_hyb(gene_name):
    return geneID_to_hyb[gene_name]

def map_to_chrom(gene_name):
    return geneID_to_chrom[gene_name]

def map_to_celltype(cluster):
    return celltype_dict[cluster]

# create lookup table for hyb
geneID_to_hyb = {name:hyb for name, hyb in zip(df_refgen['Name'], df_refgen['hyb'])}

# create lookup table for chrom
geneID_to_chrom = {name:chrom for name, chrom in zip(df_refgen['Name'], df_refgen['Chrom'])}

# assign cell type
celltype_dict = {1:'Pvalb',
                 2:'Vip',
                 3:'Ndnf',
                 4:'Sst',
                 5:'Astro',
                 6:'Micro',
                 7:'Endo',
                 8:'Oligo',
                 9:'Ex'}

# read in dataframe
df_seqfish = pd.read_csv("../data/mbrain/TableS7_brain_DNAseqFISH_1Mb_voxel_coordinates_2762cells.csv")

# assign cell type
df_seqfish['celltype'] = df_seqfish['cluster label'].apply(lambda x: map_to_celltype(x))

# record hyb
df_seqfish['hyb'] = df_seqfish['geneID'].apply(lambda x: map_to_hyb(x))

# record chrom
df_seqfish['chr'] = df_seqfish['geneID'].apply(lambda x: map_to_chrom(x))

# adjust Z resolution
df_seqfish['z'] = df_seqfish['z'] * 250/103

# add dummy localization error
df_seqfish['sig_z'] = [1, ] * df_seqfish.shape[0]
df_seqfish['sig_y'] = [1, ] * df_seqfish.shape[0]
df_seqfish['sig_x'] = [1, ] * df_seqfish.shape[0]

# rename columns
df_seqfish.rename(columns = {'z':'z_hat', 'y':'y_hat', 'x':'x_hat', 
                                'fov':'FOV', 'cellID':'cell', 'rep':'replicate'}, inplace = True)

# %% [markdown]
# - This can be subsetted into spatial coordinates by
#     - `celltype`
#     - `chr`
#     - `FOV`
#     - `replicate`
#     - `cell`
# <br></br>
# - NB: A previous implementation provided a class `Cell` whose attributes store metadata and spatial coordinates.
#     - This was difficult to subset (ie. find all `Cell` instances with `chr == 'chr7'` and `celltype == 'Astro'`).
#     - In this vignette, we store sets of coordinates in a DataFrame __`chr_pts`__ that allows quick subsetting.
#         - The column `data` is itself a list of `DataFrames`.
#         - If you have a better database solution, __please submit an enhancement inquiry__ on Github!

# %%
# save results
chr_pts = {'replicate': {},
           'FOV': {},
           'cell': {},
           'finalcellID': {},
           'celltype': {},
           'chr': {},
           'XistID': {},
           'data': {}}

# group by celltype, chr, finalcellD
for i, (name, group) in enumerate(df_seqfish.groupby(by=['celltype', 'chr', 'finalcellID'])):
            
    # make copy
    _df_cell = copy.deepcopy(group)
    
    # drop columns
    _df_cell = _df_cell[['replicate', 'FOV', 'cell', 'finalcellID', 'celltype', 
                         'chr', 'hyb', 'geneID', 'XistID', 'cluster label',
                         'x_hat', 'y_hat', 'z_hat', 
                         'sig_x', 'sig_y', 'sig_z']]

    # sort by hyb_rnd
    _df_cell = _df_cell.sort_values(by=['hyb'])

    # reset index
    _df_cell.reset_index(inplace=True, drop = True)

    # save df
    chr_pts['replicate'][i] = _df_cell.iloc[0]['replicate']
    chr_pts['FOV'][i] = _df_cell.iloc[0]['FOV']
    chr_pts['cell'][i] = _df_cell.iloc[0]['cell']
    chr_pts['finalcellID'][i] = _df_cell.iloc[0]['finalcellID']
    chr_pts['celltype'][i] = _df_cell.iloc[0]['celltype']
    chr_pts['chr'][i] = _df_cell.iloc[0]['chr']
    chr_pts['XistID'][i] = False in np.isnan(_df_cell['XistID']).tolist()
    chr_pts['data'][i] = _df_cell
            
chr_pts = pd.DataFrame(chr_pts)

# %%
chr_pts
# Out:
#        replicate  FOV  cell  finalcellID celltype   chr  XistID  \
# 0              2    0     5            3    Astro  chr1   False
# 1              2    0    11            9    Astro  chr1   False
# 2              2    0    24           20    Astro  chr1   False
# 3              2    0    36           29    Astro  chr1   False
# 4              2    0    43           34    Astro  chr1   False
# ...          ...  ...   ...          ...      ...   ...     ...
# 54276          4    6   248         2586      Vip  chrX   False
# 54277          4    7    50         2639      Vip  chrX   False
# 54278          4    7    70         2652      Vip  chrX    True
# 54279          4    7   121         2686      Vip  chrX   False
# 54280          4    7   133         2693      Vip  chrX   False
#
#                                                     data
# 0         replicate  FOV  cell  finalcellID celltype ...
# 1         replicate  FOV  cell  finalcellID celltype ...
# 2          replicate  FOV  cell  finalcellID celltype...
# 3          replicate  FOV  cell  finalcellID celltype...
# 4           replicate  FOV  cell  finalcellID celltyp...
# ...                                                  ...
# 54276      replicate  FOV  cell  finalcellID celltype...
# 54277      replicate  FOV  cell  finalcellID celltype...
# 54278       replicate  FOV  cell  finalcellID celltyp...
# 54279       replicate  FOV  cell  finalcellID celltyp...
# 54280       replicate  FOV  cell  finalcellID celltyp...
#
# [54281 rows x 8 columns]

# %% [markdown]
# ### Spatial genome alignment
#
# - Say we wanted to find the median distance matrix of `chosen_chrom = 'chr19'` among `chosen_celltype = 'Ex'` neurons.
#     - We use polymer fiber karyotyping (`jie.aligner.find_all_chr`) on sets of coordinates per cell, for a given chromosome.
#         - `nm_per_bp` is the __distance parameter__ (a.k.a. conversion factor from genomic distance b.p. --> spatial distance nm)
#         - `num_skip` is the __number of loci__ each node is allowed to look ahead, in case false positives need to be skipped.
#         - `total_num_skip_frac` is the __fraction of total imaging sequence length__ considered sufficiently long to be designated as a chromatin fiber
#         - `init_num_skip_frac` is the __fraction of total imaging sequence length__ the initial __source__ is allowed to look ahead. This parameter also allows nodes near the end of the chromosome to look ahead towards the __sink__.

# %%
import pickle

if __name__ == '__main__':
    
    chosen_chrom = 'chr19'
    chosen_celltype = 'Ex'    
    
    # grab candidate coordinates
    sel_chr_pts = chr_pts[(chr_pts['celltype'] == chosen_celltype) &
                          (chr_pts['chr'] == chosen_chrom)]['data'].tolist()
    
    # grab reference genome
    gene_dist = df_refgen[df_refgen['Chrom'] == chosen_chrom]['delta']
    
    # estimate bin size
    loci_starts = df_refgen[df_refgen['Chrom'] == chosen_chrom]['Start']
    intervals = [j-i for i, j in zip(loci_starts[:-1], loci_starts[1:])]
    bin_size = np.median(intervals)
    
    # read in parameters
    with open('../data/params/mbrain_Ex_2022_params_1mb_dipc.pkl', 'rb') as f:
        params = pickle.load(f)   
    nm_per_bp, tsf, isf = params[chosen_chrom]

    # set params
    nm_per_bps = [nm_per_bp,] * len(sel_chr_pts)
    num_skips = [15,] * len(sel_chr_pts) 
    bin_sizes = [bin_size,] * len(sel_chr_pts)
    total_num_skip_fracs = [tsf,] * len(sel_chr_pts)
    init_num_skip_fracs = [isf,] * len(sel_chr_pts)
    gene_dists = [gene_dist.values,] * len(sel_chr_pts)

    with Pool(1) as p:
        res = list(tqdm.tqdm(p.istarmap(aligner.find_all_chr, zip(sel_chr_pts, gene_dists, bin_sizes,
                                                                  nm_per_bps, num_skips, 
                                                                  total_num_skip_fracs,
                                                                  init_num_skip_fracs)), total = len(sel_chr_pts)))
# Out:
#   0%|▎                                                                               | 6/1810 [00:01<09:49,  3.06it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   0%|▎                                                                               | 7/1810 [00:02<10:06,  2.97it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   0%|▍                                                                               | 9/1810 [00:02<07:15,  4.14it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   1%|▋                                                                              | 16/1810 [00:03<07:04,  4.22it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   1%|▊                                                                              | 20/1810 [00:05<09:12,  3.24it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   1%|█▏                                                                             | 26/1810 [00:06<06:42,  4.43it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   2%|█▎                                                                             | 31/1810 [00:07<08:02,  3.69it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   2%|█▌                                                                             | 35/1810 [00:08<04:48,  6.15it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   2%|█▋                                                                             | 38/1810 [00:08<04:50,  6.10it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   2%|█▋                                                                             | 40/1810 [00:09<04:00,  7.35it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   3%|██▎                                                                            | 53/1810 [00:13<09:45,  3.00it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   3%|██▍                                                                            | 57/1810 [00:14<09:05,  3.21it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   3%|██▌                                                                            | 58/1810 [00:14<07:35,  3.85it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   4%|███                                                                            | 69/1810 [00:17<07:35,  3.83it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   4%|███                                                                            | 71/1810 [00:17<06:52,  4.22it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   4%|███▎                                                                           | 76/1810 [00:19<07:06,  4.07it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   5%|███▌                                                                           | 83/1810 [00:20<07:31,  3.82it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   5%|███▋                                                                           | 84/1810 [00:21<08:14,  3.49it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   5%|███▊                                                                           | 86/1810 [00:21<09:00,  3.19it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   6%|████▍                                                                         | 102/1810 [00:24<03:02,  9.33it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   6%|████▋                                                                         | 108/1810 [00:24<02:29, 11.35it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   8%|██████▍                                                                       | 149/1810 [00:34<09:18,  2.98it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   9%|██████▊                                                                       | 157/1810 [00:36<06:32,  4.22it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   9%|██████▊                                                                       | 159/1810 [00:36<06:20,  4.34it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   9%|██████▉                                                                       | 160/1810 [00:36<06:25,  4.29it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   9%|██████▉                                                                       | 161/1810 [00:37<07:31,  3.65it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   9%|██████▉                                                                       | 162/1810 [00:37<06:21,  4.32it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   9%|███████▏                                                                      | 166/1810 [00:38<08:25,  3.25it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   9%|███████▏                                                                      | 168/1810 [00:39<06:46,  4.04it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#   9%|███████▎                                                                      | 170/1810 [00:39<07:25,  3.68it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  10%|███████▌                                                                      | 175/1810 [00:41<08:43,  3.12it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  11%|████████▎                                                                     | 194/1810 [00:45<04:48,  5.60it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  11%|████████▌                                                                     | 200/1810 [00:46<04:25,  6.06it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  11%|████████▋                                                                     | 203/1810 [00:46<05:07,  5.22it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  12%|█████████▍                                                                    | 218/1810 [00:49<05:54,  4.49it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  13%|██████████▎                                                                   | 238/1810 [00:54<04:31,  5.79it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  13%|██████████▍                                                                   | 241/1810 [00:55<06:36,  3.95it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  14%|██████████▋                                                                   | 249/1810 [00:58<10:03,  2.59it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  14%|██████████▉                                                                   | 255/1810 [01:00<07:36,  3.41it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  15%|███████████▋                                                                  | 272/1810 [01:05<08:05,  3.17it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  15%|███████████▊                                                                  | 274/1810 [01:05<06:22,  4.02it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  15%|███████████▊                                                                  | 275/1810 [01:05<07:14,  3.53it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  16%|████████████▏                                                                 | 283/1810 [01:08<06:53,  3.69it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  16%|████████████▎                                                                 | 285/1810 [01:08<06:37,  3.84it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  16%|████████████▌                                                                 | 291/1810 [01:10<06:31,  3.88it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  16%|████████████▋                                                                 | 293/1810 [01:10<05:08,  4.91it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  17%|████████████▉                                                                 | 299/1810 [01:11<05:34,  4.52it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  17%|█████████████                                                                 | 304/1810 [01:12<05:54,  4.25it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  17%|█████████████▏                                                                | 305/1810 [01:13<06:38,  3.77it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  18%|█████████████▋                                                                | 319/1810 [01:15<03:18,  7.53it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  18%|█████████████▉                                                                | 324/1810 [01:15<04:11,  5.91it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  18%|██████████████▏                                                               | 328/1810 [01:16<04:17,  5.76it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  18%|██████████████▎                                                               | 333/1810 [01:17<04:27,  5.52it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  19%|██████████████▍                                                               | 336/1810 [01:18<04:38,  5.30it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  19%|██████████████▋                                                               | 340/1810 [01:19<06:29,  3.77it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  19%|██████████████▊                                                               | 345/1810 [01:20<06:00,  4.06it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  20%|███████████████▎                                                              | 355/1810 [01:22<07:00,  3.46it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  20%|███████████████▍                                                              | 358/1810 [01:23<08:24,  2.88it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  20%|███████████████▋                                                              | 363/1810 [01:25<08:53,  2.71it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  21%|████████████████▋                                                             | 387/1810 [01:32<07:32,  3.15it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  22%|████████████████▉                                                             | 394/1810 [01:34<07:05,  3.32it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  22%|█████████████████                                                             | 397/1810 [01:35<06:48,  3.46it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  22%|█████████████████▏                                                            | 399/1810 [01:36<06:38,  3.54it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  22%|█████████████████▎                                                            | 402/1810 [01:36<05:06,  4.60it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  22%|█████████████████▍                                                            | 404/1810 [01:36<03:32,  6.61it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  22%|█████████████████▍                                                            | 406/1810 [01:37<03:35,  6.50it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  23%|█████████████████▋                                                            | 409/1810 [01:37<04:21,  5.37it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  23%|██████████████████▎                                                           | 425/1810 [01:41<06:29,  3.55it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  24%|██████████████████▌                                                           | 430/1810 [01:43<08:32,  2.69it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  24%|██████████████████▋                                                           | 435/1810 [01:44<07:58,  2.87it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  24%|██████████████████▊                                                           | 436/1810 [01:44<06:56,  3.30it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  24%|██████████████████▉                                                           | 440/1810 [01:46<07:48,  2.92it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  25%|███████████████████▏                                                          | 444/1810 [01:47<06:54,  3.30it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  25%|███████████████████▍                                                          | 450/1810 [01:48<04:59,  4.54it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  25%|███████████████████▍                                                          | 452/1810 [01:48<05:19,  4.25it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  25%|███████████████████▌                                                          | 453/1810 [01:49<05:09,  4.38it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  26%|████████████████████                                                          | 465/1810 [01:52<07:52,  2.85it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  26%|████████████████████                                                          | 466/1810 [01:52<08:21,  2.68it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  26%|████████████████████▍                                                         | 475/1810 [01:56<07:35,  2.93it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  26%|████████████████████▌                                                         | 476/1810 [01:56<08:38,  2.57it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  27%|████████████████████▋                                                         | 481/1810 [01:57<06:54,  3.21it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  27%|████████████████████▊                                                         | 482/1810 [01:58<06:19,  3.50it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  27%|████████████████████▊                                                         | 484/1810 [01:58<06:17,  3.51it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  27%|████████████████████▉                                                         | 487/1810 [01:59<05:11,  4.25it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  27%|█████████████████████▎                                                        | 494/1810 [02:01<04:38,  4.73it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  28%|█████████████████████▉                                                        | 510/1810 [02:03<02:48,  7.70it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  28%|██████████████████████▏                                                       | 514/1810 [02:03<02:04, 10.38it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  29%|██████████████████████▎                                                       | 517/1810 [02:04<02:07, 10.18it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  29%|██████████████████████▌                                                       | 523/1810 [02:04<02:01, 10.58it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  30%|███████████████████████▋                                                      | 549/1810 [02:14<08:19,  2.53it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  31%|███████████████████████▉                                                      | 556/1810 [02:17<09:30,  2.20it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  31%|████████████████████████▏                                                     | 561/1810 [02:19<10:35,  1.97it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  33%|█████████████████████████▍                                                    | 591/1810 [02:32<09:21,  2.17it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  33%|█████████████████████████▉                                                    | 602/1810 [02:36<05:42,  3.53it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  33%|█████████████████████████▉                                                    | 603/1810 [02:36<05:19,  3.78it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  34%|██████████████████████████▌                                                   | 615/1810 [02:38<02:34,  7.74it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  34%|██████████████████████████▌                                                   | 617/1810 [02:38<02:45,  7.20it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  34%|██████████████████████████▊                                                   | 623/1810 [02:39<03:48,  5.18it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  35%|███████████████████████████▏                                                  | 631/1810 [02:41<05:03,  3.88it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  35%|███████████████████████████▌                                                  | 640/1810 [02:44<06:20,  3.08it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  36%|███████████████████████████▉                                                  | 649/1810 [02:47<07:05,  2.73it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  36%|████████████████████████████▏                                                 | 654/1810 [02:48<05:37,  3.42it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  37%|████████████████████████████▌                                                 | 663/1810 [02:52<08:45,  2.18it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  37%|████████████████████████████▊                                                 | 669/1810 [02:54<06:48,  2.79it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  37%|████████████████████████████▉                                                 | 671/1810 [02:55<08:11,  2.32it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  38%|█████████████████████████████▍                                                | 684/1810 [02:59<06:25,  2.92it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  38%|█████████████████████████████▋                                                | 689/1810 [03:01<06:36,  2.83it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  38%|█████████████████████████████▊                                                | 691/1810 [03:02<06:05,  3.06it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  38%|█████████████████████████████▉                                                | 695/1810 [03:03<04:56,  3.76it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  38%|█████████████████████████████▉                                                | 696/1810 [03:03<04:41,  3.95it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  39%|██████████████████████████████                                                | 697/1810 [03:03<04:34,  4.05it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  39%|██████████████████████████████▎                                               | 704/1810 [03:05<04:00,  4.60it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  39%|██████████████████████████████▍                                               | 707/1810 [03:05<03:44,  4.92it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  39%|██████████████████████████████▋                                               | 711/1810 [03:06<04:09,  4.41it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  39%|██████████████████████████████▋                                               | 712/1810 [03:06<04:46,  3.83it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  40%|███████████████████████████████                                               | 720/1810 [03:08<04:03,  4.48it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  40%|███████████████████████████████▎                                              | 728/1810 [03:09<01:58,  9.09it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  42%|████████████████████████████████▌                                             | 757/1810 [03:19<06:22,  2.75it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  43%|█████████████████████████████████▎                                            | 773/1810 [03:24<06:57,  2.48it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  43%|█████████████████████████████████▋                                            | 782/1810 [03:27<04:54,  3.49it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  43%|█████████████████████████████████▊                                            | 785/1810 [03:28<04:20,  3.94it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  44%|█████████████████████████████████▉                                            | 788/1810 [03:28<04:33,  3.73it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  44%|██████████████████████████████████▏                                           | 793/1810 [03:30<04:50,  3.50it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  44%|██████████████████████████████████▏                                           | 794/1810 [03:30<04:43,  3.58it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  44%|██████████████████████████████████▍                                           | 798/1810 [03:31<05:07,  3.30it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  44%|██████████████████████████████████▋                                           | 804/1810 [03:32<02:52,  5.82it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  45%|██████████████████████████████████▉                                           | 810/1810 [03:34<03:48,  4.39it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  45%|██████████████████████████████████▉                                           | 811/1810 [03:34<03:46,  4.41it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  45%|███████████████████████████████████▎                                          | 818/1810 [03:35<03:40,  4.49it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  46%|███████████████████████████████████▊                                          | 831/1810 [03:40<05:36,  2.91it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  46%|████████████████████████████████████▏                                         | 841/1810 [03:43<04:52,  3.32it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  47%|████████████████████████████████████▎                                         | 844/1810 [03:45<07:19,  2.20it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  47%|████████████████████████████████████▍                                         | 845/1810 [03:46<07:46,  2.07it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  47%|████████████████████████████████████▌                                         | 847/1810 [03:46<06:54,  2.32it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  47%|████████████████████████████████████▉                                         | 858/1810 [03:50<05:59,  2.65it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  48%|█████████████████████████████████████▏                                        | 863/1810 [03:52<04:42,  3.35it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  48%|█████████████████████████████████████▎                                        | 867/1810 [03:54<05:48,  2.70it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  49%|██████████████████████████████████████▏                                       | 885/1810 [04:01<05:22,  2.87it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  49%|██████████████████████████████████████▍                                       | 893/1810 [04:03<04:19,  3.53it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  50%|███████████████████████████████████████                                       | 906/1810 [04:07<04:49,  3.12it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  50%|███████████████████████████████████████                                       | 907/1810 [04:07<04:38,  3.24it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  50%|███████████████████████████████████████▏                                      | 909/1810 [04:08<03:54,  3.85it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  50%|███████████████████████████████████████▎                                      | 911/1810 [04:08<04:07,  3.64it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  50%|███████████████████████████████████████▎                                      | 913/1810 [04:09<04:12,  3.56it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  50%|███████████████████████████████████████▍                                      | 914/1810 [04:09<03:58,  3.75it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  51%|███████████████████████████████████████▍                                      | 916/1810 [04:09<02:46,  5.36it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  52%|████████████████████████████████████████▋                                     | 943/1810 [04:16<03:38,  3.96it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  52%|████████████████████████████████████████▊                                     | 947/1810 [04:17<05:11,  2.77it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  52%|████████████████████████████████████████▉                                     | 950/1810 [04:18<05:42,  2.51it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  53%|████████████████████████████████████████▉                                     | 951/1810 [04:19<04:29,  3.19it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  53%|█████████████████████████████████████████▎                                    | 959/1810 [04:22<05:54,  2.40it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  53%|█████████████████████████████████████████▎                                    | 960/1810 [04:22<05:07,  2.77it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  55%|██████████████████████████████████████████▌                                   | 987/1810 [04:31<05:09,  2.66it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  55%|██████████████████████████████████████████▋                                  | 1004/1810 [04:39<04:59,  2.69it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  56%|██████████████████████████████████████████▊                                  | 1006/1810 [04:39<04:57,  2.70it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  56%|██████████████████████████████████████████▉                                  | 1009/1810 [04:40<04:39,  2.87it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  56%|███████████████████████████████████████████▎                                 | 1017/1810 [04:43<05:06,  2.58it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  56%|███████████████████████████████████████████▎                                 | 1018/1810 [04:43<04:45,  2.77it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  56%|███████████████████████████████████████████▎                                 | 1019/1810 [04:44<04:14,  3.10it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  56%|███████████████████████████████████████████▍                                 | 1020/1810 [04:44<04:31,  2.91it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  56%|███████████████████████████████████████████▍                                 | 1022/1810 [04:44<03:21,  3.92it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  57%|███████████████████████████████████████████▌                                 | 1025/1810 [04:45<02:22,  5.53it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  57%|███████████████████████████████████████████▉                                 | 1033/1810 [04:46<01:24,  9.18it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  58%|████████████████████████████████████████████▋                                | 1049/1810 [04:52<05:39,  2.24it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  59%|█████████████████████████████████████████████                                | 1060/1810 [04:56<04:39,  2.68it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  59%|█████████████████████████████████████████████▎                               | 1064/1810 [04:58<06:02,  2.06it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  59%|█████████████████████████████████████████████▍                               | 1068/1810 [05:00<05:57,  2.07it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  60%|██████████████████████████████████████████████▎                              | 1090/1810 [05:11<05:52,  2.04it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  61%|██████████████████████████████████████████████▋                              | 1098/1810 [05:14<05:16,  2.25it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  62%|███████████████████████████████████████████████▌                             | 1118/1810 [05:22<04:47,  2.41it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  62%|███████████████████████████████████████████████▊                             | 1124/1810 [05:24<03:09,  3.62it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  62%|███████████████████████████████████████████████▉                             | 1128/1810 [05:25<02:52,  3.96it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  63%|████████████████████████████████████████████████▊                            | 1146/1810 [05:28<02:26,  4.53it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  64%|█████████████████████████████████████████████████                            | 1154/1810 [05:31<03:15,  3.36it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  65%|█████████████████████████████████████████████████▊                           | 1172/1810 [05:37<03:34,  2.97it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  65%|█████████████████████████████████████████████████▉                           | 1174/1810 [05:37<03:51,  2.75it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  66%|██████████████████████████████████████████████████▌                          | 1188/1810 [05:43<03:52,  2.67it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  66%|███████████████████████████████████████████████████                          | 1200/1810 [05:48<04:20,  2.34it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  66%|███████████████████████████████████████████████████▏                         | 1202/1810 [05:49<04:14,  2.38it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  67%|███████████████████████████████████████████████████▎                         | 1205/1810 [05:51<04:49,  2.09it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  67%|███████████████████████████████████████████████████▍                         | 1208/1810 [05:52<03:47,  2.64it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  67%|███████████████████████████████████████████████████▍                         | 1210/1810 [05:52<03:12,  3.11it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  67%|███████████████████████████████████████████████████▋                         | 1215/1810 [05:53<02:06,  4.71it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  67%|███████████████████████████████████████████████████▊                         | 1218/1810 [05:54<02:15,  4.37it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  68%|███████████████████████████████████████████████████▉                         | 1222/1810 [05:55<02:47,  3.50it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  68%|████████████████████████████████████████████████████                         | 1223/1810 [05:55<02:45,  3.54it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  68%|████████████████████████████████████████████████████▏                        | 1228/1810 [05:57<03:15,  2.98it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  68%|████████████████████████████████████████████████████▌                        | 1236/1810 [06:01<05:25,  1.76it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  69%|████████████████████████████████████████████████████▊                        | 1242/1810 [06:05<05:05,  1.86it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  69%|████████████████████████████████████████████████████▉                        | 1245/1810 [06:05<03:24,  2.77it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  69%|█████████████████████████████████████████████████████▎                       | 1254/1810 [06:09<03:31,  2.63it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  69%|█████████████████████████████████████████████████████▍                       | 1257/1810 [06:11<04:42,  1.96it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  70%|█████████████████████████████████████████████████████▉                       | 1268/1810 [06:16<04:06,  2.20it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  70%|██████████████████████████████████████████████████████                       | 1272/1810 [06:17<02:57,  3.03it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  71%|██████████████████████████████████████████████████████▍                      | 1280/1810 [06:19<02:25,  3.64it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  71%|██████████████████████████████████████████████████████▋                      | 1285/1810 [06:22<04:01,  2.17it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  72%|███████████████████████████████████████████████████████▌                     | 1307/1810 [06:26<02:11,  3.83it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  72%|███████████████████████████████████████████████████████▋                     | 1309/1810 [06:27<02:30,  3.33it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  72%|███████████████████████████████████████████████████████▊                     | 1311/1810 [06:27<01:49,  4.57it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  74%|████████████████████████████████████████████████████████▊                    | 1336/1810 [06:34<01:31,  5.17it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  74%|█████████████████████████████████████████████████████████▎                   | 1346/1810 [06:37<02:26,  3.17it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  74%|█████████████████████████████████████████████████████████▎                   | 1347/1810 [06:37<02:16,  3.39it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  77%|███████████████████████████████████████████████████████████                  | 1387/1810 [06:54<02:55,  2.41it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  78%|███████████████████████████████████████████████████████████▊                 | 1406/1810 [07:01<02:04,  3.24it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  78%|████████████████████████████████████████████████████████████▏                | 1415/1810 [07:06<03:38,  1.81it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  79%|████████████████████████████████████████████████████████████▌                | 1423/1810 [07:10<03:08,  2.05it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  79%|████████████████████████████████████████████████████████████▋                | 1428/1810 [07:11<02:26,  2.61it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  80%|█████████████████████████████████████████████████████████████▎               | 1441/1810 [07:17<02:49,  2.17it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  80%|█████████████████████████████████████████████████████████████▍               | 1444/1810 [07:17<01:25,  4.26it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  80%|█████████████████████████████████████████████████████████████▋               | 1450/1810 [07:18<01:31,  3.91it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  80%|█████████████████████████████████████████████████████████████▉               | 1455/1810 [07:19<01:09,  5.14it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  81%|██████████████████████████████████████████████████████████████               | 1459/1810 [07:19<00:43,  8.09it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  81%|██████████████████████████████████████████████████████████████▏              | 1463/1810 [07:20<01:12,  4.77it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  81%|██████████████████████████████████████████████████████████████▎              | 1465/1810 [07:20<00:56,  6.07it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  81%|██████████████████████████████████████████████████████████████▍              | 1467/1810 [07:21<00:48,  7.01it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  82%|██████████████████████████████████████████████████████████████▉              | 1479/1810 [07:27<02:41,  2.05it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  82%|███████████████████████████████████████████████████████████████              | 1481/1810 [07:28<02:42,  2.03it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  82%|███████████████████████████████████████████████████████████████              | 1483/1810 [07:28<01:49,  2.98it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  82%|███████████████████████████████████████████████████████████████▏             | 1484/1810 [07:29<01:48,  2.99it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  82%|███████████████████████████████████████████████████████████████▌             | 1493/1810 [07:32<01:48,  2.92it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  83%|████████████████████████████████████████████████████████████████▏            | 1510/1810 [07:38<01:12,  4.12it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  85%|█████████████████████████████████████████████████████████████████▋           | 1543/1810 [07:53<02:03,  2.15it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  85%|█████████████████████████████████████████████████████████████████▊           | 1547/1810 [07:54<01:22,  3.18it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  86%|█████████████████████████████████████████████████████████████████▊           | 1548/1810 [07:54<01:40,  2.61it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  86%|██████████████████████████████████████████████████████████████████▎          | 1559/1810 [07:59<01:37,  2.56it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  86%|██████████████████████████████████████████████████████████████████▌          | 1565/1810 [08:02<01:46,  2.30it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  87%|██████████████████████████████████████████████████████████████████▌          | 1566/1810 [08:02<01:42,  2.37it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  87%|██████████████████████████████████████████████████████████████████▊          | 1571/1810 [08:04<01:25,  2.79it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  87%|███████████████████████████████████████████████████████████████████▎         | 1581/1810 [08:07<01:16,  3.01it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  87%|███████████████████████████████████████████████████████████████████▎         | 1582/1810 [08:07<01:18,  2.92it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  88%|███████████████████████████████████████████████████████████████████▍         | 1586/1810 [08:08<00:42,  5.28it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  88%|███████████████████████████████████████████████████████████████████▊         | 1593/1810 [08:09<00:32,  6.71it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  88%|███████████████████████████████████████████████████████████████████▊         | 1594/1810 [08:09<00:37,  5.79it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  89%|████████████████████████████████████████████████████████████████████▌        | 1613/1810 [08:18<01:15,  2.60it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  89%|████████████████████████████████████████████████████████████████████▋        | 1615/1810 [08:19<01:14,  2.61it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  89%|████████████████████████████████████████████████████████████████████▊        | 1619/1810 [08:21<01:31,  2.09it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  90%|█████████████████████████████████████████████████████████████████████        | 1623/1810 [08:22<01:18,  2.39it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  90%|█████████████████████████████████████████████████████████████████████▎       | 1629/1810 [08:25<01:19,  2.27it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  91%|█████████████████████████████████████████████████████████████████████▊       | 1640/1810 [08:29<01:19,  2.13it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  91%|██████████████████████████████████████████████████████████████████████▏      | 1649/1810 [08:33<01:19,  2.03it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  92%|██████████████████████████████████████████████████████████████████████▌      | 1658/1810 [08:37<01:07,  2.26it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  92%|██████████████████████████████████████████████████████████████████████▌      | 1660/1810 [08:37<00:47,  3.16it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  93%|███████████████████████████████████████████████████████████████████████▎     | 1677/1810 [08:46<01:09,  1.91it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  93%|███████████████████████████████████████████████████████████████████████▊     | 1687/1810 [08:50<00:42,  2.88it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  93%|███████████████████████████████████████████████████████████████████████▉     | 1691/1810 [08:51<00:38,  3.08it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  94%|████████████████████████████████████████████████████████████████████████     | 1693/1810 [08:52<00:41,  2.82it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  94%|████████████████████████████████████████████████████████████████████████▌    | 1705/1810 [08:54<00:20,  5.24it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  94%|████████████████████████████████████████████████████████████████████████▋    | 1708/1810 [08:55<00:17,  5.73it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  94%|████████████████████████████████████████████████████████████████████████▋    | 1710/1810 [08:55<00:13,  7.46it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  95%|█████████████████████████████████████████████████████████████████████████▍   | 1725/1810 [08:59<00:28,  2.98it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  95%|█████████████████████████████████████████████████████████████████████████▍   | 1726/1810 [09:00<00:29,  2.89it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  96%|█████████████████████████████████████████████████████████████████████████▋   | 1732/1810 [09:02<00:33,  2.35it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  97%|██████████████████████████████████████████████████████████████████████████▎  | 1748/1810 [09:09<00:26,  2.30it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  97%|██████████████████████████████████████████████████████████████████████████▋  | 1756/1810 [09:12<00:21,  2.52it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  98%|███████████████████████████████████████████████████████████████████████████▏ | 1766/1810 [09:16<00:18,  2.41it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  98%|███████████████████████████████████████████████████████████████████████████▊ | 1781/1810 [09:22<00:12,  2.25it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  99%|████████████████████████████████████████████████████████████████████████████ | 1789/1810 [09:25<00:08,  2.50it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  99%|████████████████████████████████████████████████████████████████████████████▏| 1791/1810 [09:26<00:06,  3.06it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
#  99%|████████████████████████████████████████████████████████████████████████████▎| 1795/1810 [09:27<00:06,  2.39it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# 100%|████████████████████████████████████████████████████████████████████████████▋| 1802/1810 [09:29<00:02,  3.30it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# 100%|████████████████████████████████████████████████████████████████████████████▉| 1808/1810 [09:30<00:00,  4.78it/s]Warning at src/paths/dijkstra.c:441 : Couldn't reach some vertices
# 100%|█████████████████████████████████████████████████████████████████████████████| 1810/1810 [09:31<00:00,  3.17it/s]

# %% [markdown]
# - The result is a `list` of `list`s, where each sublist contains DataFrames of putative chromatin fibers.
# - Empty lists denote no likely fiber found; the length of the list is used to assign a __karyotype__.

# %%
print(len(res[0]), len(res[5]), len(res[55]))
# Out:
# 0 2 3

# %% [markdown]
# - We can flatten all putative chromatin fibers and calculate the median distance matrix.

# %%
# flatten
res_flat = [fiber for cell_res in res for fiber in cell_res]
med_dist_mat = plot.calc_med_dist_mat(res_flat, len(gene_dist))

# plot
fig, axs = plt.subplots(figsize = (5, 5))
axs.imshow(med_dist_mat, cmap = 'seismic_r')

# %% [markdown]
# - We can also inspect structural heterogeneity at the single cell level:

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

cmap = plt.get_cmap("seismic_r")
cmap.set_bad("gray")

fig, axs = plt.subplots(3, 3, figsize = (15, 15))
example_idxs = [556, 729, 1259, 1355, 1498, 1629, 1751, 1787, 1937]
for idx, ax in zip(example_idxs, axs.flatten()):
    
    # median distance matrix for single fiber
    mat = plot.calc_med_dist_mat([res_flat[idx]], len(gene_dist))
    
    # grab metadata
    rep, fov, cellid = res_flat[idx].iloc[0]['replicate'], res_flat[idx].iloc[0]['FOV'], res_flat[idx].iloc[0]['finalcellID']
    
    # show
    ax.imshow(mat, cmap = cmap)
    ax.set_title("Replicate{0}-FOV{1}-Cell{2} : {3}".format(rep, fov, cellid, chosen_chrom))
# Out:
# /tmp/ipykernel_1358551/170347527.py:5: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("seismic_r").copy()
#   cmap.set_bad("gray")

# %% [markdown]
# - We can compare to __proximity-ligation sequencing__ to inspect the spatial genome aligned structures.
#     - To compare _cell-type specific_ single-cell mouse brain 3D genome, we look to __Dip-C__ data ([GSE146397](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE146397))
#     - We extracted these contact frequencies using [Straw](https://github.com/aidenlab/straw) at 1 Mb resolution.
#     <br></br>
#     - Extracted `numpy` matrices of contact frequencies are provided in `jie/data/npy/dipc`)
#         - Of note, some of the imaged loci lie in the same ~ 1 Mb bin. Still others are not imaged at all.
#             - In the case of "doubly" imaged loci, we keep the contacts corresponding to the earliest bin w.r.t. the starting locus of the chromosome.
#             - In the case of an unimaged loci, we omit the binned contacts altogether.
#             - Vice versa, if a loci is imaged but too few reads mapped to the corresponding bin, this is dropped from the spatial distance matrix
#             - These dropped bin indeces are saved under `jie/data/npy/dipc/{celltype}/*_droppedidx.npy`.

# %%
import matplotlib.patheffects as pe
from numpy.ma import masked_array

# load dipc matrix
hic_mat = np.load("../data/npy/dipc/{0}/{0}_seqfish_{1}_1Mb_hic.npy".format(chosen_celltype, chosen_chrom))
dropped = np.load("../data/npy/dipc/{0}/{0}_seqfish_{1}_1Mb_hic_droppedidx.npy".format(chosen_celltype, chosen_chrom))

# reorder distance matrix to match hic contact matrix shape
remap_hyb = {}
counter = 0
for hyb in range(len(gene_dist)):
    if hyb not in dropped:
        remap_hyb[hyb] = counter
        counter +=1

# NB: One bin not imaged, drop
chroms_flatten = [chrom[chrom['geneID'] != 'Mid1'] for chrom in res_flat]

# drop mismatched bins from spatial coordinates
chroms_flattened_dropped = []
for chrom_pts in chroms_flatten:
    _df = copy.deepcopy(chrom_pts)
    _df = _df[~_df['hyb'].isin(dropped)]
    _df['Old hyb'] = _df['hyb']
    _df['hyb'] = [remap_hyb[hyb] for hyb in _df['Old hyb']]
    chroms_flattened_dropped.append(_df)

# calculate spatial distance matrix
dist_mat = plot.calc_med_dist_mat(chroms_flattened_dropped, hic_mat.shape[0])

# make hic-dist split matrix
split_up = masked_array(hic_mat, np.logical_not(np.triu(np.ones(hic_mat.shape[0])) > 0))
split_low = masked_array(dist_mat, np.logical_not(np.tril(np.ones(hic_mat.shape[0])) > 0))

### PLOT ###
fig, axs = plt.subplots(figsize = (5, 5))
cmap_dist = plt.get_cmap("seismic_r")
cmap_hic = plt.get_cmap("Reds")
cmap_dist.set_bad(alpha=0)
cmap_hic.set_bad(alpha=0)
axs.imshow(np.clip(split_up, 0, 400), cmap = cmap_hic)
axs.imshow(np.clip(split_low*100, 0, 3000), cmap = cmap_dist)
axs.set_title("{}".format(chosen_chrom), fontsize=27)

# annotate
axs.text(32, 5, "Dip-C", color = "black", fontsize = 25, fontweight='bold')
axs.text(1, 43, "seqFISH+", color="white", fontsize = 25, fontweight='bold',
         path_effects=[pe.withStroke(linewidth=4, foreground="dimgray")])

# set plot parameters
axs.tick_params(axis='both',      
                which='both',     
                bottom=False,     
                top=False,        
                left = False,
                right = False,
                labelleft = False,
                labelbottom=False) 

# add title
plt.suptitle("{} - 1 Mb".format(chosen_celltype), fontsize = 30, y=1.1)
# Out:
# /tmp/ipykernel_1358551/1163564718.py:39: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("seismic_r").copy()
#   cmap_dist.set_bad(alpha=0)
# /tmp/ipykernel_1358551/1163564718.py:40: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("Reds").copy()
#   cmap_hic.set_bad(alpha=0)
# Text(0.5, 1.1, 'Ex - 1 Mb')

# %% [markdown]
# - We can plot the Spearman correlation between the contact frequency and spatial genome aligner determined distances.

# %%
from scipy.stats import spearmanr, gaussian_kde

# calculate spearman corr
corr, p = spearmanr(hic_mat.flatten(), dist_mat.flatten(), nan_policy = 'omit')

# KDE
x = np.log(dist_mat.flatten())
y = np.log(hic_mat.flatten())
drop_indeces = set(np.where(np.isinf(x))[0]).union(np.where(np.isinf(y))[0]) # remove inf
nan_indeces = set(np.where(np.isnan(x))[0]).union(np.where(np.isnan(y))[0]) # remove nans
drop_indeces = drop_indeces.union(nan_indeces)

x = [x[i] for i in range(len(x)) if i not in drop_indeces]
y = [y[i] for i in range(len(y)) if i not in drop_indeces]

xy = np.vstack([x, y])
z = gaussian_kde(xy)(xy)
density = z.argsort()

# plot
fig, axs = plt.subplots(figsize = (5, 5))
axs.scatter([x[i] for i in density],
                                    [y[i] for i in density],
                                    c=[z[i] for i in density],
                                    cmap = 'plasma',
                                    alpha = 0.3)

axs.set_title("{}".format(chosen_chrom), fontsize=25)
axs.set_xlim(-3.5, 5)
axs.set_ylim(-1, 10)
axs.patch.set_edgecolor('black')
axs.patch.set_linewidth('1')
axs.annotate('r = {0:.2g}'.format(corr), xy=(-2.75, -0), fontsize = 25)

# set plot parameters
axs.tick_params(axis='both',      
                which='major',     
                bottom=False,     
                top=False,        
                left = False,
                right = False,
                labelleft = True,
                labelbottom=True,
                labelsize = 20) 

fig.text(0.5, -0.04, 'Distance (nm; log) - 1Mb', 
         ha="center", va="center", fontsize = 20 )
fig.text(-0.04, 0.5, 'Dip-C Contact Frequency \n (KR-norm; log)', 
         ha="center", va="center", rotation=90, fontsize = 20)
plt.xticks(np.arange(0, 4, 1.0))
plt.suptitle("{} - 1 Mb".format(chosen_celltype), fontsize = 30, y = 1.1)
# Out:
# Text(0.5, 1.1, 'Ex - 1 Mb')
